# %% [markdown]
# # Projet MLOps Pompiers

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.linear_model import LinearRegression
import lightgbm as lgb
from sklearn.ensemble import RandomForestRegressor

# %%
incidents = pd.read_csv(r"LFB_Incident_data_Last_3_years.csv")
mobilisation = pd.read_csv(r"LFB_Mobilisation_data_Last_3_years.csv")

# %% [markdown]
# ## Exploration & Pre-processing

# %% [markdown]
# Dataset "Incidents"

# %%
incidents.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392806 entries, 0 to 392805
# Data columns (total 39 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   IncidentNumber                          392806 non-null  object
#  1   DateOfCall                              392806 non-null  object
#  2   CalYear                                 392806 non-null  int64
#  3   TimeOfCall                              392806 non-null  object
#  4   HourOfCall                              392806 non-null  int64
#  5   IncidentGroup                           392806 non-null  object
#  6   StopCodeDescription                     392806 non-null  object
#  7   SpecialServiceType                      140955 non-null  object
#  8   PropertyCategory                        392806 non-null  object
#  9   PropertyType                            392806 non-null  object
#  10  AddressQualifier                        392806 non-null  object
#  11  Postcode_full                           171056 non-null  object
#  12  Postcode_district                       392806 non-null  object
#  13  UPRN                                    392806 non-null  int64
#  14  USRN                                    392806 non-null  int64
#  15  IncGeo_BoroughCode                      392806 non-null  object
#  16  IncGeo_BoroughName                      392806 non-null  object
#  17  ProperCase                              392806 non-null  object
#  18  IncGeo_WardCode                         392777 non-null  object
#  19  IncGeo_WardName                         392777 non-null  object
#  20  IncGeo_WardNameNew                      392777 non-null  object
#  21  Easting_m                               171056 non-null  float64
#  22  Northing_m                              171056 non-null  float64
#  23  Easting_rounded                         392806 non-null  int64
#  24  Northing_rounded                        392806 non-null  int64
#  25  Latitude                                171056 non-null  float64
#  26  Longitude                               171056 non-null  float64
#  27  FRS                                     392806 non-null  object
#  28  IncidentStationGround                   392805 non-null  object
#  29  FirstPumpArriving_AttendanceTime        369831 non-null  float64
#  30  FirstPumpArriving_DeployedFromStation   369826 non-null  object
#  31  SecondPumpArriving_AttendanceTime       143003 non-null  float64
#  32  SecondPumpArriving_DeployedFromStation  143001 non-null  object
#  33  NumStationsWithPumpsAttending           387219 non-null  float64
#  34  NumPumpsAttending                       387219 non-null  float64
#  35  PumpCount                               389500 non-null  float64
#  36  PumpHoursRoundUp                        389392 non-null  float64
#  37  Notional Cost (£)                       389392 non-null  float64
#  38  NumCalls                                392803 non-null  float64
# dtypes: float64(12), int64(6), object(21)
# memory usage: 116.9+ MB

# %%
incidents.isna().sum()
# Out:
# IncidentNumber                                 0
# DateOfCall                                     0
# CalYear                                        0
# TimeOfCall                                     0
# HourOfCall                                     0
# IncidentGroup                                  0
# StopCodeDescription                            0
# SpecialServiceType                        251851
# PropertyCategory                               0
# PropertyType                                   0
# AddressQualifier                               0
# Postcode_full                             221750
# Postcode_district                              0
# UPRN                                           0
# USRN                                           0
# IncGeo_BoroughCode                             0
# IncGeo_BoroughName                             0
# ProperCase                                     0
# IncGeo_WardCode                               29
# IncGeo_WardName                               29
# IncGeo_WardNameNew                            29
# Easting_m                                 221750
# Northing_m                                221750
# Easting_rounded                                0
# Northing_rounded                               0
# Latitude                                  221750
# Longitude                                 221750
# FRS                                            0
# IncidentStationGround                          1
# FirstPumpArriving_AttendanceTime           22975
# FirstPumpArriving_DeployedFromStation      22980
# SecondPumpArriving_AttendanceTime         249803
# SecondPumpArriving_DeployedFromStation    249805
# NumStationsWithPumpsAttending               5587
# NumPumpsAttending                           5587
# PumpCount                                   3306
# PumpHoursRoundUp                            3414
# Notional Cost (£)                           3414
# NumCalls                                       3
# dtype: int64

# %%
incidents.duplicated().sum()
# Out:
# 0

# %%
#Liste des colonnes à supprimer du dataframe incidents :
incid_cols = ['CalYear', 'HourOfCall', 'SpecialServiceType', 'AddressQualifier', 'Postcode_full',
             'UPRN', 'USRN','IncGeo_BoroughName', 'IncGeo_WardName', 'IncGeo_WardNameNew', 'ProperCase', 'Easting_m', 'Northing_m', 'Latitude',
               'Longitude', 'FRS','SecondPumpArriving_AttendanceTime',
                 'SecondPumpArriving_DeployedFromStation', 'Notional Cost (£)']

# %%
df_incid = incidents.drop(columns=incid_cols, axis=1)

# %%
df_incid.dropna(subset=['FirstPumpArriving_AttendanceTime', 'IncGeo_WardCode', 'IncidentStationGround', 'NumCalls'], inplace=True)

# %%
df_incid.isna().sum()
# Out:
# IncidentNumber                            0
# DateOfCall                                0
# TimeOfCall                                0
# IncidentGroup                             0
# StopCodeDescription                       0
# PropertyCategory                          0
# PropertyType                              0
# Postcode_district                         0
# IncGeo_BoroughCode                        0
# IncGeo_WardCode                           0
# Easting_rounded                           0
# Northing_rounded                          0
# IncidentStationGround                     0
# FirstPumpArriving_AttendanceTime          0
# FirstPumpArriving_DeployedFromStation     5
# NumStationsWithPumpsAttending             0
# NumPumpsAttending                         0
# PumpCount                                 0
# PumpHoursRoundUp                         90
# NumCalls                                  0
# dtype: int64

# %%
# Remplacer les 11 NaN de DeployedFromStation par les valeurs respectives de IncidentStationGround :
df_incid['FirstPumpArriving_DeployedFromStation'] = df_incid['FirstPumpArriving_DeployedFromStation'].fillna(df_incid['IncidentStationGround'])
df_incid.isna().sum()
# Out:
# IncidentNumber                            0
# DateOfCall                                0
# TimeOfCall                                0
# IncidentGroup                             0
# StopCodeDescription                       0
# PropertyCategory                          0
# PropertyType                              0
# Postcode_district                         0
# IncGeo_BoroughCode                        0
# IncGeo_WardCode                           0
# Easting_rounded                           0
# Northing_rounded                          0
# IncidentStationGround                     0
# FirstPumpArriving_AttendanceTime          0
# FirstPumpArriving_DeployedFromStation     0
# NumStationsWithPumpsAttending             0
# NumPumpsAttending                         0
# PumpCount                                 0
# PumpHoursRoundUp                         90
# NumCalls                                  0
# dtype: int64

# %%
df_incid.shape
# Out:
# (369802, 20)

# %%
df_incid['TimeOfCall'] = df_incid['DateOfCall'] + ' ' + df_incid['TimeOfCall']
df_incid.drop(['DateOfCall'], axis=1, inplace=True)
df_incid['TimeOfCall'] = pd.to_datetime(df_incid['TimeOfCall'], format='%d %b %Y %H:%M:%S')

# %%
df_incid['TimeOfCall'].head()
# Out:
# 1   2020-01-01 00:06:30
# 3   2020-01-01 00:11:05
# 4   2020-01-01 00:11:16
# 5   2020-01-01 00:12:02
# 6   2020-01-01 00:12:52
# Name: TimeOfCall, dtype: datetime64[ns]

# %%
df_incid.dtypes
# Out:
# IncidentNumber                                   object
# TimeOfCall                               datetime64[ns]
# IncidentGroup                                    object
# StopCodeDescription                              object
# PropertyCategory                                 object
# PropertyType                                     object
# Postcode_district                                object
# IncGeo_BoroughCode                               object
# IncGeo_WardCode                                  object
# Easting_rounded                                   int64
# Northing_rounded                                  int64
# IncidentStationGround                            object
# FirstPumpArriving_AttendanceTime                float64
# FirstPumpArriving_DeployedFromStation            object
# NumStationsWithPumpsAttending                   float64
# NumPumpsAttending                               float64
# PumpCount                                       float64
# PumpHoursRoundUp                                float64
# NumCalls                                        float64
# dtype: object

# %% [markdown]
# ## Dataset "Mobilisation"

# %%
mobilisation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 576892 entries, 0 to 576891
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   IncidentNumber            576892 non-null  object
#  1   CalYear                   576892 non-null  int64
#  2   HourOfCall                576892 non-null  int64
#  3   ResourceMobilisationId    576892 non-null  int64
#  4   Resource_Code             576892 non-null  object
#  5   PerformanceReporting      576892 non-null  object
#  6   DateAndTimeMobilised      576892 non-null  object
#  7   DateAndTimeMobile         574442 non-null  object
#  8   DateAndTimeArrived        576892 non-null  object
#  9   TurnoutTimeSeconds        574430 non-null  float64
#  10  TravelTimeSeconds         574426 non-null  float64
#  11  AttendanceTimeSeconds     576892 non-null  int64
#  12  DateAndTimeLeft           576645 non-null  object
#  13  DateAndTimeReturned       0 non-null       float64
#  14  DeployedFromStation_Code  576883 non-null  object
#  15  DeployedFromStation_Name  576883 non-null  object
#  16  DeployedFromLocation      576487 non-null  object
#  17  PumpOrder                 576892 non-null  int64
#  18  PlusCode_Code             576892 non-null  object
#  19  PlusCode_Description      576892 non-null  object
#  20  DelayCodeId               132637 non-null  float64
#  21  DelayCode_Description     132637 non-null  object
# dtypes: float64(4), int64(5), object(13)
# memory usage: 96.8+ MB

# %%
mobilisation.isna().sum()
# Out:
# IncidentNumber                   0
# CalYear                          0
# HourOfCall                       0
# ResourceMobilisationId           0
# Resource_Code                    0
# PerformanceReporting             0
# DateAndTimeMobilised             0
# DateAndTimeMobile             2450
# DateAndTimeArrived               0
# TurnoutTimeSeconds            2462
# TravelTimeSeconds             2466
# AttendanceTimeSeconds            0
# DateAndTimeLeft                247
# DateAndTimeReturned         576892
# DeployedFromStation_Code         9
# DeployedFromStation_Name         9
# DeployedFromLocation           405
# PumpOrder                        0
# PlusCode_Code                    0
# PlusCode_Description             0
# DelayCodeId                 444255
# DelayCode_Description       444255
# dtype: int64

# %%
mobilisation.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Conserver uniquement les 1ères forces arrivées sur site

# %%
df_mobil = mobilisation[['IncidentNumber', 'DateAndTimeMobilised','AttendanceTimeSeconds',
                     'DeployedFromStation_Name','DeployedFromLocation', 'PumpOrder', 'DelayCodeId']]

# %%
df_mobil['DelayCodeId'].value_counts()
# Out:
# DelayCodeId
# 12.0    81936
# 9.0     26318
# 8.0      9895
# 5.0      6732
# 7.0      2024
# 11.0     1790
# 13.0     1406
# 10.0     1334
# 6.0       715
# 3.0       487
# Name: count, dtype: int64

# %%
# Remplacer les DelaiCodeId manquant par 1, supposant que le code 1 = pas de ralentissement.
df_mobil['DelayCodeId'] = df_mobil['DelayCodeId'].fillna(1)
# Out:
# C:\Users\w_sat\AppData\Local\Temp\ipykernel_16908\3068371128.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_mobil['DelayCodeId'] = df_mobil['DelayCodeId'].fillna(1)

# %%
df_mobil.isna().sum()
# Out:
# IncidentNumber                0
# DateAndTimeMobilised          0
# AttendanceTimeSeconds         0
# DeployedFromStation_Name      9
# DeployedFromLocation        405
# PumpOrder                     0
# DelayCodeId                   0
# dtype: int64

# %%
df_mobil = df_mobil.dropna()

# %%
df_mobil.dtypes
# Out:
# IncidentNumber               object
# DateAndTimeMobilised         object
# AttendanceTimeSeconds         int64
# DeployedFromStation_Name     object
# DeployedFromLocation         object
# PumpOrder                     int64
# DelayCodeId                 float64
# dtype: object

# %%
df_mobil['DeployedFromLocation'].value_counts()
# Out:
# DeployedFromLocation
# Home Station     556835
# Other Station     19650
# Name: count, dtype: int64

# %%
df_mobil['DelayCodeId'] = df_mobil['DelayCodeId'].astype('int')

# %%
df_mobil.shape
# Out:
# (576485, 7)

# %% [markdown]
# ## Merge des deux Dataset

# %%
df = pd.merge(left=df_mobil, right=df_incid, on='IncidentNumber', how='left')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 576485 entries, 0 to 576484
# Data columns (total 25 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   IncidentNumber                         576485 non-null  object
#  1   DateAndTimeMobilised                   576485 non-null  object
#  2   AttendanceTimeSeconds                  576485 non-null  int64
#  3   DeployedFromStation_Name               576485 non-null  object
#  4   DeployedFromLocation                   576485 non-null  object
#  5   PumpOrder                              576485 non-null  int64
#  6   DelayCodeId                            576485 non-null  int32
#  7   TimeOfCall                             574039 non-null  datetime64[ns]
#  8   IncidentGroup                          574039 non-null  object
#  9   StopCodeDescription                    574039 non-null  object
#  10  PropertyCategory                       574039 non-null  object
#  11  PropertyType                           574039 non-null  object
#  12  Postcode_district                      574039 non-null  object
#  13  IncGeo_BoroughCode                     574039 non-null  object
#  14  IncGeo_WardCode                        574039 non-null  object
#  15  Easting_rounded                        574039 non-null  float64
#  16  Northing_rounded                       574039 non-null  float64
#  17  IncidentStationGround                  574039 non-null  object
#  18  FirstPumpArriving_AttendanceTime       574039 non-null  float64
#  19  FirstPumpArriving_DeployedFromStation  574039 non-null  object
#  20  NumStationsWithPumpsAttending          574039 non-null  float64
#  21  NumPumpsAttending                      574039 non-null  float64
#  22  PumpCount                              574039 non-null  float64
#  23  PumpHoursRoundUp                       573917 non-null  float64
#  24  NumCalls                               574039 non-null  float64
# dtypes: datetime64[ns](1), float64(8), int32(1), int64(2), object(13)
# memory usage: 107.8+ MB

# %%
df['Year'] = df['TimeOfCall'].dt.year
df['DayOfWeek'] = df['TimeOfCall'].dt.dayofweek
df['Hour'] = df['TimeOfCall'].dt.hour

# %%
df.drop(columns=['IncidentNumber','TimeOfCall', 'DateAndTimeMobilised', 'DeployedFromStation_Name',
 'Postcode_district', 'PropertyType', 'NumCalls',
                  'FirstPumpArriving_AttendanceTime', 'FirstPumpArriving_DeployedFromStation'], axis = 1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 576485 entries, 0 to 576484
# Data columns (total 19 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   AttendanceTimeSeconds          576485 non-null  int64
#  1   DeployedFromLocation           576485 non-null  object
#  2   PumpOrder                      576485 non-null  int64
#  3   DelayCodeId                    576485 non-null  int32
#  4   IncidentGroup                  574039 non-null  object
#  5   StopCodeDescription            574039 non-null  object
#  6   PropertyCategory               574039 non-null  object
#  7   IncGeo_BoroughCode             574039 non-null  object
#  8   IncGeo_WardCode                574039 non-null  object
#  9   Easting_rounded                574039 non-null  float64
#  10  Northing_rounded               574039 non-null  float64
#  11  IncidentStationGround          574039 non-null  object
#  12  NumStationsWithPumpsAttending  574039 non-null  float64
#  13  NumPumpsAttending              574039 non-null  float64
#  14  PumpCount                      574039 non-null  float64
#  15  PumpHoursRoundUp               573917 non-null  float64
#  16  Year                           574039 non-null  float64
#  17  DayOfWeek                      574039 non-null  float64
#  18  Hour                           574039 non-null  float64
# dtypes: float64(9), int32(1), int64(2), object(7)
# memory usage: 81.4+ MB

# %%
df.head()
# Out:
#    AttendanceTimeSeconds DeployedFromLocation  PumpOrder  DelayCodeId  \
# 0                    324         Home Station          1            1
# 1                    195         Home Station          1            1
# 2                    426         Home Station          1            9
# 3                    292         Home Station          2            1
# 4                    249         Home Station          1            1
#
#   IncidentGroup StopCodeDescription   PropertyCategory IncGeo_BoroughCode  \
# 0          Fire        Primary Fire    Non Residential          E09000017
# 1   False Alarm                 AFA    Non Residential          E09000027
# 2          Fire      Secondary Fire  Outdoor Structure          E09000010
# 3          Fire        Primary Fire    Non Residential          E09000017
# 4   False Alarm                 AFA  Other Residential          E09000032
#
#   IncGeo_WardCode  Easting_rounded  Northing_rounded IncidentStationGround  \
# 0       E05013566         506750.0          181550.0            Hillingdon
# 1       E05013786         518250.0          174850.0              Richmond
# 2       E05013685         535350.0          194250.0              Edmonton
# 3       E05013566         506750.0          181550.0            Hillingdon
# 4       E05014024         527750.0          171150.0               Tooting
#
#    NumStationsWithPumpsAttending  NumPumpsAttending  PumpCount  \
# 0                            1.0                2.0        2.0
# 1                            1.0                1.0        1.0
# 2                            1.0                1.0        1.0
# 3                            1.0                2.0        2.0
# 4                            1.0                2.0        2.0
#
#    PumpHoursRoundUp    Year  DayOfWeek  Hour
# 0               1.0  2020.0        2.0   0.0
# 1               1.0  2020.0        2.0   0.0
# 2               1.0  2020.0        2.0   0.0
# 3               1.0  2020.0        2.0   0.0
# 4               2.0  2020.0        2.0   0.0

# %%
df.isna().sum()
# Out:
# AttendanceTimeSeconds               0
# DeployedFromLocation                0
# PumpOrder                           0
# DelayCodeId                         0
# IncidentGroup                    2446
# StopCodeDescription              2446
# PropertyCategory                 2446
# IncGeo_BoroughCode               2446
# IncGeo_WardCode                  2446
# Easting_rounded                  2446
# Northing_rounded                 2446
# IncidentStationGround            2446
# NumStationsWithPumpsAttending    2446
# NumPumpsAttending                2446
# PumpCount                        2446
# PumpHoursRoundUp                 2568
# Year                             2446
# DayOfWeek                        2446
# Hour                             2446
# dtype: int64

# %%
df = df.dropna()

# %% [markdown]
# ## Get Dummies

# %%
dummies_cols = ['IncidentGroup','StopCodeDescription', 'PropertyCategory', 'DeployedFromLocation']

# %%
df = pd.get_dummies(df, columns=dummies_cols)

# %%
num_cols = ['NumStationsWithPumpsAttending', 'NumPumpsAttending', 'DelayCodeId']
df[num_cols] = df[num_cols].astype(int)

# %%
string_cols = ['IncGeo_BoroughCode', 'IncGeo_WardCode', 'IncidentStationGround']

df[string_cols] = df[string_cols].astype(str)

# %% [markdown]
# ## Label Encoder

# %%
label_encoder = LabelEncoder()
df_encoded = df[string_cols].apply(label_encoder.fit_transform)

# %%
df.drop(string_cols, axis=1, inplace=True)

# %%
df = df.join(df_encoded)

# %%
df.dtypes
# Out:
# AttendanceTimeSeconds                                   int64
# PumpOrder                                               int64
# DelayCodeId                                             int32
# Easting_rounded                                       float64
# Northing_rounded                                      float64
# NumStationsWithPumpsAttending                           int32
# NumPumpsAttending                                       int32
# PumpCount                                             float64
# PumpHoursRoundUp                                      float64
# Year                                                  float64
# DayOfWeek                                             float64
# Hour                                                  float64
# IncidentGroup_False Alarm                                bool
# IncidentGroup_Fire                                       bool
# IncidentGroup_Special Service                            bool
# StopCodeDescription_AFA                                  bool
# StopCodeDescription_Chimney Fire                         bool
# StopCodeDescription_False alarm - Good intent            bool
# StopCodeDescription_False alarm - Malicious              bool
# StopCodeDescription_Late Call                            bool
# StopCodeDescription_Primary Fire                         bool
# StopCodeDescription_Secondary Fire                       bool
# StopCodeDescription_Special Service                      bool
# StopCodeDescription_Use of Special Operations Room       bool
# PropertyCategory_Aircraft                                bool
# PropertyCategory_Boat                                    bool
# PropertyCategory_Dwelling                                bool
# PropertyCategory_Non Residential                         bool
# PropertyCategory_Other Residential                       bool
# PropertyCategory_Outdoor                                 bool
# PropertyCategory_Outdoor Structure                       bool
# PropertyCategory_Rail Vehicle                            bool
# PropertyCategory_Road Vehicle                            bool
# DeployedFromLocation_Home Station                        bool
# DeployedFromLocation_Other Station                       bool
# IncGeo_BoroughCode                                      int32
# IncGeo_WardCode                                         int32
# IncidentStationGround                                   int32
# dtype: object

# %% [markdown]
# ## Correlation

# %%
correlation_matrix = df.corr()

# %%
correlation_matrix
# Out:
#                                                     AttendanceTimeSeconds  \
# AttendanceTimeSeconds                                            1.000000
# PumpOrder                                                        0.393634
# DelayCodeId                                                      0.523697
# Easting_rounded                                                 -0.023204
# Northing_rounded                                                 0.032766
# NumStationsWithPumpsAttending                                    0.246801
# NumPumpsAttending                                                0.221587
# PumpCount                                                        0.172868
# PumpHoursRoundUp                                                 0.055324
# Year                                                             0.039363
# DayOfWeek                                                       -0.000189
# Hour                                                            -0.017696
# IncidentGroup_False Alarm                                        0.018361
# IncidentGroup_Fire                                               0.049326
# IncidentGroup_Special Service                                   -0.064736
# StopCodeDescription_AFA                                         -0.020326
# StopCodeDescription_Chimney Fire                                 0.000407
# StopCodeDescription_False alarm - Good intent                    0.057531
# StopCodeDescription_False alarm - Malicious                      0.003847
# StopCodeDescription_Late Call                                    0.002123
# StopCodeDescription_Primary Fire                                 0.060339
# StopCodeDescription_Secondary Fire                              -0.001391
# StopCodeDescription_Special Service                             -0.064739
# StopCodeDescription_Use of Special Operations Room               0.001061
# PropertyCategory_Aircraft                                        0.018243
# PropertyCategory_Boat                                            0.014815
# PropertyCategory_Dwelling                                        0.043046
# PropertyCategory_Non Residential                                -0.074341
# PropertyCategory_Other Residential                              -0.018228
# PropertyCategory_Outdoor                                         0.029810
# PropertyCategory_Outdoor Structure                              -0.013609
# PropertyCategory_Rail Vehicle                                    0.001115
# PropertyCategory_Road Vehicle                                    0.024847
# DeployedFromLocation_Home Station                               -0.023103
# DeployedFromLocation_Other Station                               0.023103
# IncGeo_BoroughCode                                              -0.068138
# IncGeo_WardCode                                                  0.007188
# IncidentStationGround                                            0.005842
#
#                                                     PumpOrder  DelayCodeId  \
# AttendanceTimeSeconds                                0.393634     0.523697
# PumpOrder                                            1.000000    -0.181946
# DelayCodeId                                         -0.181946     1.000000
# Easting_rounded                                      0.013335    -0.030679
# Northing_rounded                                    -0.000748     0.022052
# NumStationsWithPumpsAttending                        0.650103    -0.147173
# NumPumpsAttending                                    0.701534    -0.185899
# PumpCount                                            0.510404    -0.127564
# PumpHoursRoundUp                                     0.085351    -0.004945
# Year                                                -0.010161     0.046565
# DayOfWeek                                            0.010108    -0.006016
# Hour                                                 0.011008    -0.019754
# IncidentGroup_False Alarm                            0.208034    -0.100189
# IncidentGroup_Fire                                   0.019218     0.016987
# IncidentGroup_Special Service                       -0.258163     0.101218
# StopCodeDescription_AFA                              0.162623    -0.101067
# StopCodeDescription_Chimney Fire                    -0.002746     0.002214
# StopCodeDescription_False alarm - Good intent        0.058278     0.006542
# StopCodeDescription_False alarm - Malicious          0.015895    -0.006817
# StopCodeDescription_Late Call                       -0.002546     0.004898
# StopCodeDescription_Primary Fire                     0.101655    -0.016085
# StopCodeDescription_Secondary Fire                  -0.103231     0.047872
# StopCodeDescription_Special Service                 -0.258161     0.101210
# StopCodeDescription_Use of Special Operations Room  -0.000783     0.002493
# PropertyCategory_Aircraft                            0.011033     0.004192
# PropertyCategory_Boat                                0.012406    -0.002394
# PropertyCategory_Dwelling                            0.177522    -0.050733
# PropertyCategory_Non Residential                    -0.114799     0.001622
# PropertyCategory_Other Residential                   0.033726    -0.032411
# PropertyCategory_Outdoor                            -0.093989     0.071445
# PropertyCategory_Outdoor Structure                  -0.066301     0.019150
# PropertyCategory_Rail Vehicle                        0.004479    -0.005435
# PropertyCategory_Road Vehicle                       -0.078222     0.050198
# DeployedFromLocation_Home Station                    0.001549    -0.031577
# DeployedFromLocation_Other Station                  -0.001549     0.031577
# IncGeo_BoroughCode                                   0.051010    -0.092610
# IncGeo_WardCode                                     -0.029112     0.018546
# IncidentStationGround                               -0.006982     0.011309
#
#                                                     Easting_rounded  \
# AttendanceTimeSeconds                                     -0.023204
# PumpOrder                                                  0.013335
# DelayCodeId                                               -0.030679
# Easting_rounded                                            1.000000
# Northing_rounded                                           0.041095
# NumStationsWithPumpsAttending                              0.038411
# NumPumpsAttending                                          0.017946
# PumpCount                                                  0.018092
# PumpHoursRoundUp                                           0.009780
# Year                                                      -0.005235
# DayOfWeek                                                  0.000734
# Hour                                                       0.001607
# IncidentGroup_False Alarm                                 -0.053928
# IncidentGroup_Fire                                         0.032340
# IncidentGroup_Special Service                              0.034052
# StopCodeDescription_AFA                                   -0.067238
# StopCodeDescription_Chimney Fire                          -0.002718
# StopCodeDescription_False alarm - Good intent              0.018294
# StopCodeDescription_False alarm - Malicious                0.011700
# StopCodeDescription_Late Call                              0.000214
# StopCodeDescription_Primary Fire                           0.016361
# StopCodeDescription_Secondary Fire                         0.029822
# StopCodeDescription_Special Service                        0.034051
# StopCodeDescription_Use of Special Operations Room         0.000053
# PropertyCategory_Aircraft                                 -0.064120
# PropertyCategory_Boat                                     -0.008145
# PropertyCategory_Dwelling                                 -0.002703
# PropertyCategory_Non Residential                          -0.026151
# PropertyCategory_Other Residential                        -0.005716
# PropertyCategory_Outdoor                                   0.027110
# PropertyCategory_Outdoor Structure                         0.023467
# PropertyCategory_Rail Vehicle                             -0.002580
# PropertyCategory_Road Vehicle                              0.016298
# DeployedFromLocation_Home Station                         -0.003585
# DeployedFromLocation_Other Station                         0.003585
# IncGeo_BoroughCode                                        -0.007559
# IncGeo_WardCode                                            0.162743
# IncidentStationGround                                     -0.113412
#
#                                                     Northing_rounded  \
# AttendanceTimeSeconds                                       0.032766
# PumpOrder                                                  -0.000748
# DelayCodeId                                                 0.022052
# Easting_rounded                                             0.041095
# Northing_rounded                                            1.000000
# NumStationsWithPumpsAttending                              -0.009297
# NumPumpsAttending                                           0.000992
# PumpCount                                                   0.004115
# PumpHoursRoundUp                                            0.005592
# Year                                                       -0.006719
# DayOfWeek                                                   0.007196
# Hour                                                       -0.001389
# IncidentGroup_False Alarm                                  -0.022545
# IncidentGroup_Fire                                          0.010601
# IncidentGroup_Special Service                               0.016807
# StopCodeDescription_AFA                                    -0.025644
# StopCodeDescription_Chimney Fire                            0.000002
# StopCodeDescription_False alarm - Good intent               0.004955
# StopCodeDescription_False alarm - Malicious                 0.001487
# StopCodeDescription_Late Call                              -0.000544
# StopCodeDescription_Primary Fire                            0.004153
# StopCodeDescription_Secondary Fire                          0.011335
# StopCodeDescription_Special Service                         0.016809
# StopCodeDescription_Use of Special Operations Room         -0.000912
# PropertyCategory_Aircraft                                  -0.017946
# PropertyCategory_Boat                                       0.004141
# PropertyCategory_Dwelling                                   0.008695
# PropertyCategory_Non Residential                           -0.013108
# PropertyCategory_Other Residential                         -0.010227
# PropertyCategory_Outdoor                                    0.001648
# PropertyCategory_Outdoor Structure                          0.009150
# PropertyCategory_Rail Vehicle                               0.003389
# PropertyCategory_Road Vehicle                               0.006097
# DeployedFromLocation_Home Station                           0.001073
# DeployedFromLocation_Other Station                         -0.001073
# IncGeo_BoroughCode                                         -0.143431
# IncGeo_WardCode                                            -0.157687
# IncidentStationGround                                       0.010332
#
#                                                     NumStationsWithPumpsAttending  \
# AttendanceTimeSeconds                                                    0.246801
# PumpOrder                                                                0.650103
# DelayCodeId                                                             -0.147173
# Easting_rounded                                                          0.038411
# Northing_rounded                                                        -0.009297
# NumStationsWithPumpsAttending                                            1.000000
# NumPumpsAttending                                                        0.926751
# PumpCount                                                                0.681908
# PumpHoursRoundUp                                                         0.126315
# Year                                                                     0.010732
# DayOfWeek                                                                0.022769
# Hour                                                                     0.020650
# IncidentGroup_False Alarm                                                0.254751
# IncidentGroup_Fire                                                       0.032441
# IncidentGroup_Special Service                                           -0.323982
# StopCodeDescription_AFA                                                  0.196384
# StopCodeDescription_Chimney Fire                                        -0.004079
# StopCodeDescription_False alarm - Good intent                            0.076271
# StopCodeDescription_False alarm - Malicious                              0.017348
# StopCodeDescription_Late Call                                           -0.003619
# StopCodeDescription_Primary Fire                                         0.139395
# StopCodeDescription_Secondary Fire                                      -0.131893
# StopCodeDescription_Special Service                                     -0.323980
# StopCodeDescription_Use of Special Operations Room                      -0.000967
# PropertyCategory_Aircraft                                                0.019649
# PropertyCategory_Boat                                                    0.016321
# PropertyCategory_Dwelling                                                0.223020
# PropertyCategory_Non Residential                                        -0.141698
# PropertyCategory_Other Residential                                       0.038070
# PropertyCategory_Outdoor                                                -0.119840
# PropertyCategory_Outdoor Structure                                      -0.083454
# PropertyCategory_Rail Vehicle                                            0.007498
# PropertyCategory_Road Vehicle                                           -0.096781
# DeployedFromLocation_Home Station                                       -0.021916
# DeployedFromLocation_Other Station                                       0.021916
# IncGeo_BoroughCode                                                       0.108160
# IncGeo_WardCode                                                         -0.075388
# IncidentStationGround                                                   -0.023485
#
#                                                     NumPumpsAttending  \
# AttendanceTimeSeconds                                        0.221587
# PumpOrder                                                    0.701534
# DelayCodeId                                                 -0.185899
# Easting_rounded                                              0.017946
# Northing_rounded                                             0.000992
# NumStationsWithPumpsAttending                                0.926751
# NumPumpsAttending                                            1.000000
# PumpCount                                                    0.734701
# PumpHoursRoundUp                                             0.134663
# Year                                                        -0.016813
# DayOfWeek                                                    0.014357
# Hour                                                         0.015732
# IncidentGroup_False Alarm                                    0.287573
# IncidentGroup_Fire                                           0.035047
# IncidentGroup_Special Service                               -0.364337
# StopCodeDescription_AFA                                      0.223284
# StopCodeDescription_Chimney Fire                            -0.003513
# StopCodeDescription_False alarm - Good intent                0.082780
# StopCodeDescription_False alarm - Malicious                  0.022299
# StopCodeDescription_Late Call                               -0.003638
# StopCodeDescription_Primary Fire                             0.153227
# StopCodeDescription_Secondary Fire                          -0.146011
# StopCodeDescription_Special Service                         -0.364335
# StopCodeDescription_Use of Special Operations Room          -0.001116
# PropertyCategory_Aircraft                                    0.017777
# PropertyCategory_Boat                                        0.018311
# PropertyCategory_Dwelling                                    0.248444
# PropertyCategory_Non Residential                            -0.162393
# PropertyCategory_Other Residential                           0.046070
# PropertyCategory_Outdoor                                    -0.132102
# PropertyCategory_Outdoor Structure                          -0.093375
# PropertyCategory_Rail Vehicle                                0.007366
# PropertyCategory_Road Vehicle                               -0.104801
# DeployedFromLocation_Home Station                           -0.001599
# DeployedFromLocation_Other Station                           0.001599
# IncGeo_BoroughCode                                           0.069667
# IncGeo_WardCode                                             -0.040787
# IncidentStationGround                                       -0.010597
#
#                                                     PumpCount  \
# AttendanceTimeSeconds                                0.172868
# PumpOrder                                            0.510404
# DelayCodeId                                         -0.127564
# Easting_rounded                                      0.018092
# Northing_rounded                                     0.004115
# NumStationsWithPumpsAttending                        0.681908
# NumPumpsAttending                                    0.734701
# PumpCount                                            1.000000
# PumpHoursRoundUp                                     0.752101
# Year                                                -0.012228
# DayOfWeek                                            0.009516
# Hour                                                 0.007454
# IncidentGroup_False Alarm                            0.148517
# IncidentGroup_Fire                                   0.106758
# IncidentGroup_Special Service                       -0.266249
# StopCodeDescription_AFA                              0.115037
# StopCodeDescription_Chimney Fire                    -0.001853
# StopCodeDescription_False alarm - Good intent        0.043177
# StopCodeDescription_False alarm - Malicious          0.011521
# StopCodeDescription_Late Call                       -0.002522
# StopCodeDescription_Primary Fire                     0.210308
# StopCodeDescription_Secondary Fire                  -0.107696
# StopCodeDescription_Special Service                 -0.266247
# StopCodeDescription_Use of Special Operations Room  -0.000821
# PropertyCategory_Aircraft                            0.011191
# PropertyCategory_Boat                                0.012895
# PropertyCategory_Dwelling                            0.161480
# PropertyCategory_Non Residential                    -0.091926
# PropertyCategory_Other Residential                   0.023789
# PropertyCategory_Outdoor                            -0.087480
# PropertyCategory_Outdoor Structure                  -0.065876
# PropertyCategory_Rail Vehicle                        0.004963
# PropertyCategory_Road Vehicle                       -0.078161
# DeployedFromLocation_Home Station                   -0.003259
# DeployedFromLocation_Other Station                   0.003259
# IncGeo_BoroughCode                                   0.042526
# IncGeo_WardCode                                     -0.026562
# IncidentStationGround                               -0.007703
#
#                                                     PumpHoursRoundUp  \
# AttendanceTimeSeconds                                       0.055324
# PumpOrder                                                   0.085351
# DelayCodeId                                                -0.004945
# Easting_rounded                                             0.009780
# Northing_rounded                                            0.005592
# NumStationsWithPumpsAttending                               0.126315
# NumPumpsAttending                                           0.134663
# PumpCount                                                   0.752101
# PumpHoursRoundUp                                            1.000000
# Year                                                       -0.003424
# DayOfWeek                                                   0.000036
# Hour                                                       -0.004441
# IncidentGroup_False Alarm                                  -0.084059
# IncidentGroup_Fire                                          0.140311
# IncidentGroup_Special Service                              -0.026105
# StopCodeDescription_AFA                                    -0.069639
# StopCodeDescription_Chimney Fire                            0.001969
# StopCodeDescription_False alarm - Good intent              -0.017454
# StopCodeDescription_False alarm - Malicious                -0.006648
# StopCodeDescription_Late Call                              -0.000390
# StopCodeDescription_Primary Fire                            0.182483
# StopCodeDescription_Secondary Fire                         -0.018147
# StopCodeDescription_Special Service                        -0.026104
# StopCodeDescription_Use of Special Operations Room         -0.000136
# PropertyCategory_Aircraft                                   0.002383
# PropertyCategory_Boat                                       0.007493
# PropertyCategory_Dwelling                                  -0.006283
# PropertyCategory_Non Residential                            0.023670
# PropertyCategory_Other Residential                         -0.015427
# PropertyCategory_Outdoor                                   -0.001051
# PropertyCategory_Outdoor Structure                         -0.005271
# PropertyCategory_Rail Vehicle                               0.005651
# PropertyCategory_Road Vehicle                              -0.005452
# DeployedFromLocation_Home Station                          -0.003224
# DeployedFromLocation_Other Station                          0.003224
# IncGeo_BoroughCode                                         -0.007033
# IncGeo_WardCode                                             0.000005
# IncidentStationGround                                      -0.001138
#
#                                                         Year  ...  \
# AttendanceTimeSeconds                               0.039363  ...
# PumpOrder                                          -0.010161  ...
# DelayCodeId                                         0.046565  ...
# Easting_rounded                                    -0.005235  ...
# Northing_rounded                                   -0.006719  ...
# NumStationsWithPumpsAttending                       0.010732  ...
# NumPumpsAttending                                  -0.016813  ...
# PumpCount                                          -0.012228  ...
# PumpHoursRoundUp                                   -0.003424  ...
# Year                                                1.000000  ...
# DayOfWeek                                          -0.000704  ...
# Hour                                               -0.007304  ...
# IncidentGroup_False Alarm                          -0.015529  ...
# IncidentGroup_Fire                                 -0.024169  ...
# IncidentGroup_Special Service                       0.039295  ...
# StopCodeDescription_AFA                             0.003033  ...
# StopCodeDescription_Chimney Fire                   -0.002485  ...
# StopCodeDescription_False alarm - Good intent      -0.026644  ...
# StopCodeDescription_False alarm - Malicious        -0.004217  ...
# StopCodeDescription_Late Call                       0.002080  ...
# StopCodeDescription_Primary Fire                   -0.018579  ...
# StopCodeDescription_Secondary Fire                 -0.013731  ...
# StopCodeDescription_Special Service                 0.039292  ...
# StopCodeDescription_Use of Special Operations Room  0.000832  ...
# PropertyCategory_Aircraft                           0.011026  ...
# PropertyCategory_Boat                              -0.002626  ...
# PropertyCategory_Dwelling                           0.011244  ...
# PropertyCategory_Non Residential                    0.012087  ...
# PropertyCategory_Other Residential                 -0.014931  ...
# PropertyCategory_Outdoor                           -0.018474  ...
# PropertyCategory_Outdoor Structure                 -0.006840  ...
# PropertyCategory_Rail Vehicle                       0.002476  ...
# PropertyCategory_Road Vehicle                      -0.003774  ...
# DeployedFromLocation_Home Station                  -0.018906  ...
# DeployedFromLocation_Other Station                  0.018906  ...
# IncGeo_BoroughCode                                 -0.004035  ...
# IncGeo_WardCode                                    -0.001365  ...
# IncidentStationGround                              -0.002072  ...
#
#                                                     PropertyCategory_Other Residential  \
# AttendanceTimeSeconds                                                        -0.018228
# PumpOrder                                                                     0.033726
# DelayCodeId                                                                  -0.032411
# Easting_rounded                                                              -0.005716
# Northing_rounded                                                             -0.010227
# NumStationsWithPumpsAttending                                                 0.038070
# NumPumpsAttending                                                             0.046070
# PumpCount                                                                     0.023789
# PumpHoursRoundUp                                                             -0.015427
# Year                                                                         -0.014931
# DayOfWeek                                                                     0.002508
# Hour                                                                         -0.007405
# IncidentGroup_False Alarm                                                     0.149636
# IncidentGroup_Fire                                                           -0.080062
# IncidentGroup_Special Service                                                -0.103003
# StopCodeDescription_AFA                                                       0.185042
# StopCodeDescription_Chimney Fire                                             -0.003266
# StopCodeDescription_False alarm - Good intent                                -0.056528
# StopCodeDescription_False alarm - Malicious                                  -0.007079
# StopCodeDescription_Late Call                                                 0.001558
# StopCodeDescription_Primary Fire                                             -0.046285
# StopCodeDescription_Secondary Fire                                           -0.065733
# StopCodeDescription_Special Service                                          -0.103002
# StopCodeDescription_Use of Special Operations Room                           -0.000348
# PropertyCategory_Aircraft                                                    -0.007405
# PropertyCategory_Boat                                                        -0.007446
# PropertyCategory_Dwelling                                                    -0.331586
# PropertyCategory_Non Residential                                             -0.118407
# PropertyCategory_Other Residential                                            1.000000
# PropertyCategory_Outdoor                                                     -0.069025
# PropertyCategory_Outdoor Structure                                           -0.050527
# PropertyCategory_Rail Vehicle                                                -0.008970
# PropertyCategory_Road Vehicle                                                -0.062129
# DeployedFromLocation_Home Station                                             0.006374
# DeployedFromLocation_Other Station                                           -0.006374
# IncGeo_BoroughCode                                                            0.000461
# IncGeo_WardCode                                                               0.002253
# IncidentStationGround                                                        -0.017183
#
#                                                     PropertyCategory_Outdoor  \
# AttendanceTimeSeconds                                               0.029810
# PumpOrder                                                          -0.093989
# DelayCodeId                                                         0.071445
# Easting_rounded                                                     0.027110
# Northing_rounded                                                    0.001648
# NumStationsWithPumpsAttending                                      -0.119840
# NumPumpsAttending                                                  -0.132102
# PumpCount                                                          -0.087480
# PumpHoursRoundUp                                                   -0.001051
# Year                                                               -0.018474
# DayOfWeek                                                           0.009003
# Hour                                                                0.053325
# IncidentGroup_False Alarm                                          -0.209525
# IncidentGroup_Fire                                                  0.268366
# IncidentGroup_Special Service                                       0.006600
# StopCodeDescription_AFA                                            -0.246674
# StopCodeDescription_Chimney Fire                                   -0.003241
# StopCodeDescription_False alarm - Good intent                       0.065673
# StopCodeDescription_False alarm - Malicious                        -0.007537
# StopCodeDescription_Late Call                                      -0.001292
# StopCodeDescription_Primary Fire                                   -0.072672
# StopCodeDescription_Secondary Fire                                  0.521023
# StopCodeDescription_Special Service                                 0.006602
# StopCodeDescription_Use of Special Operations Room                 -0.000345
# PropertyCategory_Aircraft                                          -0.007347
# PropertyCategory_Boat                                              -0.007387
# PropertyCategory_Dwelling                                          -0.328961
# PropertyCategory_Non Residential                                   -0.117470
# PropertyCategory_Other Residential                                 -0.069025
# PropertyCategory_Outdoor                                            1.000000
# PropertyCategory_Outdoor Structure                                 -0.050127
# PropertyCategory_Rail Vehicle                                      -0.008899
# PropertyCategory_Road Vehicle                                      -0.061637
# DeployedFromLocation_Home Station                                  -0.004347
# DeployedFromLocation_Other Station                                  0.004347
# IncGeo_BoroughCode                                                 -0.045920
# IncGeo_WardCode                                                     0.015497
# IncidentStationGround                                              -0.004528
#
#                                                     PropertyCategory_Outdoor Structure  \
# AttendanceTimeSeconds                                                        -0.013609
# PumpOrder                                                                    -0.066301
# DelayCodeId                                                                   0.019150
# Easting_rounded                                                               0.023467
# Northing_rounded                                                              0.009150
# NumStationsWithPumpsAttending                                                -0.083454
# NumPumpsAttending                                                            -0.093375
# PumpCount                                                                    -0.065876
# PumpHoursRoundUp                                                             -0.005271
# Year                                                                         -0.006840
# DayOfWeek                                                                     0.007981
# Hour                                                                          0.019264
# IncidentGroup_False Alarm                                                    -0.192683
# IncidentGroup_Fire                                                            0.330168
# IncidentGroup_Special Service                                                -0.067361
# StopCodeDescription_AFA                                                      -0.179440
# StopCodeDescription_Chimney Fire                                             -0.002372
# StopCodeDescription_False alarm - Good intent                                -0.013136
# StopCodeDescription_False alarm - Malicious                                  -0.004272
# StopCodeDescription_Late Call                                                -0.000946
# StopCodeDescription_Primary Fire                                              0.001961
# StopCodeDescription_Secondary Fire                                            0.520583
# StopCodeDescription_Special Service                                          -0.067360
# StopCodeDescription_Use of Special Operations Room                           -0.000253
# PropertyCategory_Aircraft                                                    -0.005378
# PropertyCategory_Boat                                                        -0.005408
# PropertyCategory_Dwelling                                                    -0.240806
# PropertyCategory_Non Residential                                             -0.085990
# PropertyCategory_Other Residential                                           -0.050527
# PropertyCategory_Outdoor                                                     -0.050127
# PropertyCategory_Outdoor Structure                                            1.000000
# PropertyCategory_Rail Vehicle                                                -0.006515
# PropertyCategory_Road Vehicle                                                -0.045120
# DeployedFromLocation_Home Station                                            -0.003599
# DeployedFromLocation_Other Station                                            0.003599
# IncGeo_BoroughCode                                                            0.001342
# IncGeo_WardCode                                                               0.012850
# IncidentStationGround                                                        -0.001118
#
#                                                     PropertyCategory_Rail Vehicle  \
# AttendanceTimeSeconds                                                    0.001115
# PumpOrder                                                                0.004479
# DelayCodeId                                                             -0.005435
# Easting_rounded                                                         -0.002580
# Northing_rounded                                                         0.003389
# NumStationsWithPumpsAttending                                            0.007498
# NumPumpsAttending                                                        0.007366
# PumpCount                                                                0.004963
# PumpHoursRoundUp                                                         0.005651
# Year                                                                     0.002476
# DayOfWeek                                                               -0.007842
# Hour                                                                     0.001186
# IncidentGroup_False Alarm                                               -0.025212
# IncidentGroup_Fire                                                       0.006795
# IncidentGroup_Special Service                                            0.023251
# StopCodeDescription_AFA                                                 -0.028193
# StopCodeDescription_Chimney Fire                                        -0.000421
# StopCodeDescription_False alarm - Good intent                            0.006473
# StopCodeDescription_False alarm - Malicious                             -0.003576
# StopCodeDescription_Late Call                                           -0.000168
# StopCodeDescription_Primary Fire                                         0.014628
# StopCodeDescription_Secondary Fire                                      -0.008475
# StopCodeDescription_Special Service                                      0.023251
# StopCodeDescription_Use of Special Operations Room                      -0.000045
# PropertyCategory_Aircraft                                               -0.000955
# PropertyCategory_Boat                                                   -0.000960
# PropertyCategory_Dwelling                                               -0.042752
# PropertyCategory_Non Residential                                        -0.015266
# PropertyCategory_Other Residential                                      -0.008970
# PropertyCategory_Outdoor                                                -0.008899
# PropertyCategory_Outdoor Structure                                      -0.006515
# PropertyCategory_Rail Vehicle                                            1.000000
# PropertyCategory_Road Vehicle                                           -0.008010
# DeployedFromLocation_Home Station                                       -0.001231
# DeployedFromLocation_Other Station                                       0.001231
# IncGeo_BoroughCode                                                       0.001027
# IncGeo_WardCode                                                          0.002219
# IncidentStationGround                                                   -0.001412
#
#                                                     PropertyCategory_Road Vehicle  \
# AttendanceTimeSeconds                                                    0.024847
# PumpOrder                                                               -0.078222
# DelayCodeId                                                              0.050198
# Easting_rounded                                                          0.016298
# Northing_rounded                                                         0.006097
# NumStationsWithPumpsAttending                                           -0.096781
# NumPumpsAttending                                                       -0.104801
# PumpCount                                                               -0.078161
# PumpHoursRoundUp                                                        -0.005452
# Year                                                                    -0.003774
# DayOfWeek                                                                0.007930
# Hour                                                                    -0.011567
# IncidentGroup_False Alarm                                               -0.252473
# IncidentGroup_Fire                                                       0.012532
# IncidentGroup_Special Service                                            0.281730
# StopCodeDescription_AFA                                                 -0.222282
# StopCodeDescription_Chimney Fire                                        -0.002917
# StopCodeDescription_False alarm - Good intent                           -0.033002
# StopCodeDescription_False alarm - Malicious                             -0.017782
# StopCodeDescription_Late Call                                           -0.001163
# StopCodeDescription_Primary Fire                                         0.059479
# StopCodeDescription_Secondary Fire                                      -0.058299
# StopCodeDescription_Special Service                                      0.281732
# StopCodeDescription_Use of Special Operations Room                      -0.000311
# PropertyCategory_Aircraft                                               -0.006613
# PropertyCategory_Boat                                                   -0.006649
# PropertyCategory_Dwelling                                               -0.296098
# PropertyCategory_Non Residential                                        -0.105735
# PropertyCategory_Other Residential                                      -0.062129
# PropertyCategory_Outdoor                                                -0.061637
# PropertyCategory_Outdoor Structure                                      -0.045120
# PropertyCategory_Rail Vehicle                                           -0.008010
# PropertyCategory_Road Vehicle                                            1.000000
# DeployedFromLocation_Home Station                                        0.001425
# DeployedFromLocation_Other Station                                      -0.001425
# IncGeo_BoroughCode                                                      -0.045427
# IncGeo_WardCode                                                          0.012742
# IncidentStationGround                                                   -0.008648
#
#                                                     DeployedFromLocation_Home Station  \
# AttendanceTimeSeconds                                                       -0.023103
# PumpOrder                                                                    0.001549
# DelayCodeId                                                                 -0.031577
# Easting_rounded                                                             -0.003585
# Northing_rounded                                                             0.001073
# NumStationsWithPumpsAttending                                               -0.021916
# NumPumpsAttending                                                           -0.001599
# PumpCount                                                                   -0.003259
# PumpHoursRoundUp                                                            -0.003224
# Year                                                                        -0.018906
# DayOfWeek                                                                    0.004698
# Hour                                                                        -0.024938
# IncidentGroup_False Alarm                                                   -0.002180
# IncidentGroup_Fire                                                           0.000971
# IncidentGroup_Special Service                                                0.001673
# StopCodeDescription_AFA                                                     -0.004992
# StopCodeDescription_Chimney Fire                                             0.001554
# StopCodeDescription_False alarm - Good intent                                0.003337
# StopCodeDescription_False alarm - Malicious                                  0.003255
# StopCodeDescription_Late Call                                               -0.001014
# StopCodeDescription_Primary Fire                                             0.002956
# StopCodeDescription_Secondary Fire                                          -0.002415
# StopCodeDescription_Special Service                                          0.001672
# StopCodeDescription_Use of Special Operations Room                           0.000248
# PropertyCategory_Aircraft                                                    0.001175
# PropertyCategory_Boat                                                        0.002587
# PropertyCategory_Dwelling                                                    0.007301
# PropertyCategory_Non Residential                                            -0.010121
# PropertyCategory_Other Residential                                           0.006374
# PropertyCategory_Outdoor                                                    -0.004347
# PropertyCategory_Outdoor Structure                                          -0.003599
# PropertyCategory_Rail Vehicle                                               -0.001231
# PropertyCategory_Road Vehicle                                                0.001425
# DeployedFromLocation_Home Station                                            1.000000
# DeployedFromLocation_Other Station                                          -1.000000
# IncGeo_BoroughCode                                                          -0.019704
# IncGeo_WardCode                                                              0.006924
# IncidentStationGround                                                       -0.000936
#
#                                                     DeployedFromLocation_Other Station  \
# AttendanceTimeSeconds                                                         0.023103
# PumpOrder                                                                    -0.001549
# DelayCodeId                                                                   0.031577
# Easting_rounded                                                               0.003585
# Northing_rounded                                                             -0.001073
# NumStationsWithPumpsAttending                                                 0.021916
# NumPumpsAttending                                                             0.001599
# PumpCount                                                                     0.003259
# PumpHoursRoundUp                                                              0.003224
# Year                                                                          0.018906
# DayOfWeek                                                                    -0.004698
# Hour                                                                          0.024938
# IncidentGroup_False Alarm                                                     0.002180
# IncidentGroup_Fire                                                           -0.000971
# IncidentGroup_Special Service                                                -0.001673
# StopCodeDescription_AFA                                                       0.004992
# StopCodeDescription_Chimney Fire                                             -0.001554
# StopCodeDescription_False alarm - Good intent                                -0.003337
# StopCodeDescription_False alarm - Malicious                                  -0.003255
# StopCodeDescription_Late Call                                                 0.001014
# StopCodeDescription_Primary Fire                                             -0.002956
# StopCodeDescription_Secondary Fire                                            0.002415
# StopCodeDescription_Special Service                                          -0.001672
# StopCodeDescription_Use of Special Operations Room                           -0.000248
# PropertyCategory_Aircraft                                                    -0.001175
# PropertyCategory_Boat                                                        -0.002587
# PropertyCategory_Dwelling                                                    -0.007301
# PropertyCategory_Non Residential                                              0.010121
# PropertyCategory_Other Residential                                           -0.006374
# PropertyCategory_Outdoor                                                      0.004347
# PropertyCategory_Outdoor Structure                                            0.003599
# PropertyCategory_Rail Vehicle                                                 0.001231
# PropertyCategory_Road Vehicle                                                -0.001425
# DeployedFromLocation_Home Station                                            -1.000000
# DeployedFromLocation_Other Station                                            1.000000
# IncGeo_BoroughCode                                                            0.019704
# IncGeo_WardCode                                                              -0.006924
# IncidentStationGround                                                         0.000936
#
#                                                     IncGeo_BoroughCode  \
# AttendanceTimeSeconds                                        -0.068138
# PumpOrder                                                     0.051010
# DelayCodeId                                                  -0.092610
# Easting_rounded                                              -0.007559
# Northing_rounded                                             -0.143431
# NumStationsWithPumpsAttending                                 0.108160
# NumPumpsAttending                                             0.069667
# PumpCount                                                     0.042526
# PumpHoursRoundUp                                             -0.007033
# Year                                                         -0.004035
# DayOfWeek                                                    -0.000220
# Hour                                                         -0.004109
# IncidentGroup_False Alarm                                     0.053510
# IncidentGroup_Fire                                           -0.030190
# IncidentGroup_Special Service                                -0.035459
# StopCodeDescription_AFA                                       0.056828
# StopCodeDescription_Chimney Fire                              0.001756
# StopCodeDescription_False alarm - Good intent                -0.007211
# StopCodeDescription_False alarm - Malicious                   0.001601
# StopCodeDescription_Late Call                                -0.002043
# StopCodeDescription_Primary Fire                             -0.014371
# StopCodeDescription_Secondary Fire                           -0.028949
# StopCodeDescription_Special Service                          -0.035461
# StopCodeDescription_Use of Special Operations Room            0.000550
# PropertyCategory_Aircraft                                    -0.003773
# PropertyCategory_Boat                                         0.006032
# PropertyCategory_Dwelling                                     0.026560
# PropertyCategory_Non Residential                              0.021368
# PropertyCategory_Other Residential                            0.000461
# PropertyCategory_Outdoor                                     -0.045920
# PropertyCategory_Outdoor Structure                            0.001342
# PropertyCategory_Rail Vehicle                                 0.001027
# PropertyCategory_Road Vehicle                                -0.045427
# DeployedFromLocation_Home Station                            -0.019704
# DeployedFromLocation_Other Station                            0.019704
# IncGeo_BoroughCode                                            1.000000
# IncGeo_WardCode                                               0.156898
# IncidentStationGround                                         0.194654
#
#                                                     IncGeo_WardCode  \
# AttendanceTimeSeconds                                      0.007188
# PumpOrder                                                 -0.029112
# DelayCodeId                                                0.018546
# Easting_rounded                                            0.162743
# Northing_rounded                                          -0.157687
# NumStationsWithPumpsAttending                             -0.075388
# NumPumpsAttending                                         -0.040787
# PumpCount                                                 -0.026562
# PumpHoursRoundUp                                           0.000005
# Year                                                      -0.001365
# DayOfWeek                                                 -0.004365
# Hour                                                       0.001192
# IncidentGroup_False Alarm                                 -0.008710
# IncidentGroup_Fire                                         0.013626
# IncidentGroup_Special Service                             -0.001901
# StopCodeDescription_AFA                                   -0.008099
# StopCodeDescription_Chimney Fire                           0.002753
# StopCodeDescription_False alarm - Good intent             -0.001621
# StopCodeDescription_False alarm - Malicious                0.002962
# StopCodeDescription_Late Call                             -0.002405
# StopCodeDescription_Primary Fire                           0.005415
# StopCodeDescription_Secondary Fire                         0.014359
# StopCodeDescription_Special Service                       -0.001908
# StopCodeDescription_Use of Special Operations Room         0.002195
# PropertyCategory_Aircraft                                 -0.011385
# PropertyCategory_Boat                                     -0.009966
# PropertyCategory_Dwelling                                 -0.027708
# PropertyCategory_Non Residential                           0.011924
# PropertyCategory_Other Residential                         0.002253
# PropertyCategory_Outdoor                                   0.015497
# PropertyCategory_Outdoor Structure                         0.012850
# PropertyCategory_Rail Vehicle                              0.002219
# PropertyCategory_Road Vehicle                              0.012742
# DeployedFromLocation_Home Station                          0.006924
# DeployedFromLocation_Other Station                        -0.006924
# IncGeo_BoroughCode                                         0.156898
# IncGeo_WardCode                                            1.000000
# IncidentStationGround                                     -0.019724
#
#                                                     IncidentStationGround
# AttendanceTimeSeconds                                            0.005842
# PumpOrder                                                       -0.006982
# DelayCodeId                                                      0.011309
# Easting_rounded                                                 -0.113412
# Northing_rounded                                                 0.010332
# NumStationsWithPumpsAttending                                   -0.023485
# NumPumpsAttending                                               -0.010597
# PumpCount                                                       -0.007703
# PumpHoursRoundUp                                                -0.001138
# Year                                                            -0.002072
# DayOfWeek                                                        0.001691
# Hour                                                            -0.006406
# IncidentGroup_False Alarm                                        0.001637
# IncidentGroup_Fire                                               0.002900
# IncidentGroup_Special Service                                   -0.004452
# StopCodeDescription_AFA                                          0.008439
# StopCodeDescription_Chimney Fire                                 0.004208
# StopCodeDescription_False alarm - Good intent                   -0.009484
# StopCodeDescription_False alarm - Malicious                     -0.003112
# StopCodeDescription_Late Call                                    0.000914
# StopCodeDescription_Primary Fire                                 0.003950
# StopCodeDescription_Secondary Fire                              -0.000849
# StopCodeDescription_Special Service                             -0.004446
# StopCodeDescription_Use of Special Operations Room              -0.001946
# PropertyCategory_Aircraft                                       -0.011880
# PropertyCategory_Boat                                           -0.002508
# PropertyCategory_Dwelling                                        0.000849
# PropertyCategory_Non Residential                                 0.020131
# PropertyCategory_Other Residential                              -0.017183
# PropertyCategory_Outdoor                                        -0.004528
# PropertyCategory_Outdoor Structure                              -0.001118
# PropertyCategory_Rail Vehicle                                   -0.001412
# PropertyCategory_Road Vehicle                                   -0.008648
# DeployedFromLocation_Home Station                               -0.000936
# DeployedFromLocation_Other Station                               0.000936
# IncGeo_BoroughCode                                               0.194654
# IncGeo_WardCode                                                 -0.019724
# IncidentStationGround                                            1.000000
#
# [38 rows x 38 columns]

# %% [markdown]
# # **Entrainement**

# %%
X = df.drop('AttendanceTimeSeconds', axis=1)
y = df['AttendanceTimeSeconds']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %% [markdown]
# Standardisation

# %%
sc = MinMaxScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# Linear Regression

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
rmse = np.sqrt(mse)
mpe = np.mean((y_test - y_pred) / y_test) * 100

# Affichage des métriques
print("Mean Squared Error (MSE): ", mse)
print("Mean Absolute Error (MAE): ", mae)
print("R-squared (R²): ", r2)
print("Root Mean Squared Error (RMSE): ", rmse)
print("Mean Percentage Error (MPE): ", mpe)

print("\nScore :")
print('score train :', lr.score(X_train, y_train))
print('score test :', lr.score(X_test, y_test))
# Out:
# Mean Squared Error (MSE):  10188.463890577113
# Mean Absolute Error (MAE):  71.62543580496846
# R-squared (R²):  0.5352101668983593
# Root Mean Squared Error (RMSE):  100.93792097411712
# Mean Percentage Error (MPE):  -45.76427241325681
#
# Score :
# score train : 0.5360154750504511
# score test : 0.5352101668983593

# %% [markdown]
# LightGBM

# %%
model_lgb = lgb.LGBMRegressor()
model_lgb.fit(X_train, y_train)

y_pred = model_lgb.predict(X_test)

# Calcul des métriques
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
rmse = np.sqrt(mse)
mpe = np.mean((y_test - y_pred) / y_test) * 100

# Affichage des métriques
print("Mean Squared Error (MSE): ", mse)
print("Mean Absolute Error (MAE): ", mae)
print("R-squared (R²): ", r2)
print("Root Mean Squared Error (RMSE): ", rmse)
# Out:
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.018021 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1160
# [LightGBM] [Info] Number of data points in the train set: 459133, number of used features: 35
# [LightGBM] [Info] Start training from score 348.932305
# Mean Squared Error (MSE):  7865.960856999302
# Mean Absolute Error (MAE):  63.450155661738094
# R-squared (R²):  0.6411609568258818
# Root Mean Squared Error (RMSE):  88.69025232233417

# %% [markdown]
# Random Forest

# %%
model_rf = RandomForestRegressor(n_estimators=100, random_state=42)  # n_estimators est le nombre d'arbres dans la forêt
model_rf.fit(X_train, y_train)
y_pred = model_rf.predict(X_test)

# Calcul des métriques
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
rmse = np.sqrt(mse)
mpe = np.mean((y_test - y_pred) / y_test) * 100

# Affichage des métriques
print("Mean Squared Error (MSE): ", mse)
print("Mean Absolute Error (MAE): ", mae)
print("R-squared (R²): ", r2)
print("Root Mean Squared Error (RMSE): ", rmse)
# Out:
# Mean Squared Error (MSE):  7462.234178561525
# Mean Absolute Error (MAE):  58.33417916327049
# R-squared (R²):  0.6595786552645369
# Root Mean Squared Error (RMSE):  86.38422413011259

# %% [markdown]
# Le Random Forest est le modèle le plus performant, mais il est aussi plus long à entrainer (11min30sec).

# %% [markdown]
# ## Test prédictions

# %%
predictions = y_pred
y_true = y

# Générer un échantillon aléatoire pour l'affichage
indices = np.random.choice(len(predictions), size=3, replace=False)

# Afficher l'échantillon
for index in indices:
    print(f"Exemple {index + 1}:")
    print(f"Valeur prédite : {predictions[index]}")
    print(f"Valeur réelle : {y_true[index]}")
    print("-" * 20)
# Out:
# Exemple 77397:
# Valeur prédite : 258.003229877379
# Valeur réelle : 321
# --------------------
# Exemple 75759:
# Valeur prédite : 341.4935891841936
# Valeur réelle : 453
# --------------------
# Exemple 25698:
# Valeur prédite : 436.9254036734475
# Valeur réelle : 486
# --------------------

# %% [markdown]
# ## **Features Selection**

# %%
# Importance des fonctionnalités
feature_importances = model_lgb.feature_importances_

# Associer les importances aux noms de fonctionnalités
feature_names = X.columns
feature_importance_dict = dict(zip(feature_names, feature_importances))

# Trier les importances des fonctionnalités par ordre croissant
sorted_importances = sorted(feature_importance_dict.items(), key=lambda x: x[1], reverse = True)

# Afficher les importances des fonctionnalités
for feature, importance in sorted_importances:
    print(f'Feature: {feature}, Importance: {importance}')
# Out:
# Feature: Northing_rounded, Importance: 567
# Feature: Easting_rounded, Importance: 551
# Feature: PumpOrder, Importance: 248
# Feature: DelayCodeId, Importance: 222
# Feature: NumStationsWithPumpsAttending, Importance: 218
# Feature: IncGeo_WardCode, Importance: 202
# Feature: Hour, Importance: 180
# Feature: NumPumpsAttending, Importance: 146
# Feature: PumpHoursRoundUp, Importance: 109
# Feature: PumpCount, Importance: 86
# Feature: IncidentStationGround, Importance: 85
# Feature: IncGeo_BoroughCode, Importance: 77
# Feature: DeployedFromLocation_Home Station, Importance: 48
# Feature: DayOfWeek, Importance: 37
# Feature: PropertyCategory_Road Vehicle, Importance: 37
# Feature: Year, Importance: 32
# Feature: IncidentGroup_Special Service, Importance: 26
# Feature: PropertyCategory_Dwelling, Importance: 23
# Feature: PropertyCategory_Outdoor, Importance: 21
# Feature: PropertyCategory_Non Residential, Importance: 18
# Feature: StopCodeDescription_AFA, Importance: 15
# Feature: StopCodeDescription_False alarm - Good intent, Importance: 14
# Feature: IncidentGroup_False Alarm, Importance: 10
# Feature: StopCodeDescription_Primary Fire, Importance: 7
# Feature: PropertyCategory_Other Residential, Importance: 5
# Feature: PropertyCategory_Aircraft, Importance: 4
# Feature: PropertyCategory_Boat, Importance: 4
# Feature: IncidentGroup_Fire, Importance: 3
# Feature: StopCodeDescription_Secondary Fire, Importance: 2
# Feature: PropertyCategory_Outdoor Structure, Importance: 2
# Feature: DeployedFromLocation_Other Station, Importance: 1
# Feature: StopCodeDescription_Chimney Fire, Importance: 0
# Feature: StopCodeDescription_False alarm - Malicious, Importance: 0
# Feature: StopCodeDescription_Late Call, Importance: 0
# Feature: StopCodeDescription_Special Service, Importance: 0
# Feature: StopCodeDescription_Use of Special Operations Room, Importance: 0
# Feature: PropertyCategory_Rail Vehicle, Importance: 0

# %%
important_features = [feature for feature, importance in feature_importance_dict.items() if importance > 50]
important_features
# Out:
# ['PumpOrder',
#  'DelayCodeId',
#  'Easting_rounded',
#  'Northing_rounded',
#  'NumStationsWithPumpsAttending',
#  'NumPumpsAttending',
#  'PumpCount',
#  'PumpHoursRoundUp',
#  'Hour',
#  'IncGeo_BoroughCode',
#  'IncGeo_WardCode',
#  'IncidentStationGround']

# %%
# Je réduit le nombre de colonnes en ne conservant que les features qui ont une importance supérieur à 50 :
df_reduced = df[['AttendanceTimeSeconds','PumpOrder',
 'DelayCodeId',
 'Easting_rounded',
 'Northing_rounded',
 'NumStationsWithPumpsAttending',
 'NumPumpsAttending',
 'PumpCount',
 'PumpHoursRoundUp',
 'Hour',
 'DeployedFromLocation_Home Station',
 'IncGeo_BoroughCode',
 'IncGeo_WardCode',
 'IncidentStationGround']]

# %%
X = df_reduced.drop('AttendanceTimeSeconds', axis=1)
y = df_reduced['AttendanceTimeSeconds']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

sc = MinMaxScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

model2_lgb = lgb.LGBMRegressor()
model2_lgb.fit(X_train, y_train)

y_pred = model2_lgb.predict(X_test)

# Calcul des métriques
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
rmse = np.sqrt(mse)
mpe = np.mean((y_test - y_pred) / y_test) * 100

# Affichage des métriques
print("Mean Squared Error (MSE): ", mse)
print("Mean Absolute Error (MAE): ", mae)
print("R-squared (R²): ", r2)
print("Root Mean Squared Error (RMSE): ", rmse)
# Out:
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.014472 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1106
# [LightGBM] [Info] Number of data points in the train set: 459133, number of used features: 13
# [LightGBM] [Info] Start training from score 349.010740
# Mean Squared Error (MSE):  7788.755388303297
# Mean Absolute Error (MAE):  63.15024187427161
# R-squared (R²):  0.6415251614899142
# Root Mean Squared Error (RMSE):  88.25392562545474

# %% [markdown]
# ### Random Forest

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    'n_estimators': [50, 100, 200],  # Nombre d'arbres dans la forêt
    'max_depth': [None, 10, 20, 30],  # Profondeur maximale des arbres
}

# %%
model_rf = RandomForestRegressor(random_state=42, n_jobs = -1)  # n_estimators est le nombre d'arbres dans la forêt

grid_search = GridSearchCV(estimator=model_rf, param_grid=param_grid, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)

grid_search.fit(X_train, y_train)
best_params = grid_search.best_params_
best_model = grid_search.best_estimator_

y_pred = best_model.predict(X_test)

# Calcul des métriques
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
rmse = np.sqrt(mse)
mpe = np.mean((y_test - y_pred) / y_test) * 100

# Affichage des métriques
print("Mean Squared Error (MSE): ", mse)
print("Mean Absolute Error (MAE): ", mae)
print("R-squared (R²): ", r2)
print("Root Mean Squared Error (RMSE): ", rmse)

# %%
best_params
